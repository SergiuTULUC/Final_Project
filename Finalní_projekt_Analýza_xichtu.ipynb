# %% [markdown]
# <a href="https://colab.research.google.com/github/SergiuTULUC/Final_Project/blob/main/Finaln%C3%AD_projekt_Anal%C3%BDza_xichtu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Zaverečný projekt Analýza xichtu

# %% [markdown]
# # import knihoven

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.9 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=8cefea30f29ccb86a2376a9a1f4e36b22d6da5c6241aa153264e9254b3cc7a9d
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
from deepface import DeepFace
# Out:
# 25-03-05 19:41:43 - Directory /root/.deepface has been created
# 25-03-05 19:41:43 - Directory /root/.deepface/weights has been created

# %% [markdown]
# ### Načtení obrázku s vělkémá, hluboce otevřenéma očíma

# %%
img = cv2.imread('0029.jpg') # načítam obrazek
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # konverze barev z BGR na RGB
img
# Out:
# array([[[187, 195, 197],
#         [187, 195, 197],
#         [187, 196, 195],
#         ...,
#         [194, 203, 202],
#         [193, 201, 203],
#         [193, 201, 203]],
#
#        [[187, 195, 197],
#         [187, 195, 197],
#         [187, 196, 195],
#         ...,
#         [194, 203, 202],
#         [194, 202, 204],
#         [194, 202, 204]],
#
#        [[188, 196, 198],
#         [188, 196, 198],
#         [188, 197, 196],
#         ...,
#         [194, 203, 202],
#         [194, 202, 204],
#         [194, 202, 204]],
#
#        ...,
#
#        [[144, 154, 156],
#         [143, 153, 155],
#         [143, 153, 155],
#         ...,
#         [182, 192, 191],
#         [181, 191, 192],
#         [181, 191, 192]],
#
#        [[143, 153, 155],
#         [143, 153, 155],
#         [143, 153, 155],
#         ...,
#         [182, 192, 191],
#         [182, 192, 193],
#         [182, 192, 193]],
#
#        [[142, 152, 154],
#         [143, 153, 155],
#         [143, 153, 155],
# ...

# %% [markdown]
# zobrazení obrázku na plotu

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# Analýza obrázku

# %%
prediction = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 25-03-05 19:41:46 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
#
#   0%|          | 0.00/5.98M [00:00<?, ?B/s]
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 29.1MB/s]
# Action: age:  25%|██▌       | 1/4 [00:01<00:04,  1.52s/it]
# 25-03-05 19:41:51 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   0%|          | 524k/539M [00:00<02:00, 4.48MB/s]
#   1%|          | 6.29M/539M [00:00<00:16, 31.6MB/s]
#   2%|▏         | 13.1M/539M [00:00<00:11, 47.1MB/s]
#   4%|▍         | 24.1M/539M [00:00<00:07, 68.9MB/s]
# ...

# %%
#Ukaž mi vysledky analýzy
prediction
# Out:
# [{'emotion': {'angry': 1.6150022866376048e-19,
#    'disgust': 1.5990041681562573e-32,
#    'fear': 2.6181668649275697e-21,
#    'happy': 99.9999821186055,
#    'sad': 6.894653800569139e-16,
#    'surprise': 1.840546461101015e-11,
#    'neutral': 1.904883191481008e-05},
#   'dominant_emotion': 'happy',
#   'region': {'x': 177,
#    'y': 0,
#    'w': 151,
#    'h': 151,
#    'left_eye': (278, 52),
#    'right_eye': (225, 50)},
#   'face_confidence': 0.9,
#   'age': 24,
#   'gender': {'Woman': 99.92006421089172, 'Man': 0.07993348990567029},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 5.936463549733162,
#    'indian': 10.275749862194061,
#    'black': 5.607523024082184,
#    'white': 10.45651063323021,
#    'middle eastern': 6.4667388796806335,
#    'latino hispanic': 61.25701665878296},
#   'dominant_race': 'latino hispanic'}]

# %%
#Co má za naladu
prediction[0]['dominant_emotion'] # Access the first element (dictionary) of the list and then access the 'dominant_emotion' key.
# Out:
# 'happy'

# %% [markdown]
# # Vyhledavaní obličee na obrázku a označení čvercem

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
#Zobrazení obrázku v černobílém formátu
plt.imshow(gray, cmap='gray')
#plt.show()
